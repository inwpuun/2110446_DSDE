# %%
# %pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.10.2)
# Requirement already satisfied: click<9,>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: entrypoints<1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.1.41)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (4.25.2)
# Requirement already satisfied: pytz<2024 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (21.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (0.4.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: Flask<4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: numpy<2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (1.23.1)
# Requirement already satisfied: scipy<2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (1.11.3)
# Requirement already satisfied: pandas<3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (2.1.4)
# Requirement already satisfied: querystring-parser<2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (2.0.26)
# Requirement already satisfied: scikit-learn<2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (1.4.0)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (15.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: matplotlib<4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.7.3)
# Requirement already satisfied: gunicorn<22 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: Mako in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas<3->mlflow) (2023.4)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (2022.6.15)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import the libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

import mlflow
import mlflow.sklearn

# %%
# 1
df = pd.read_csv('https://raw.githubusercontent.com/pvateekul/2110446_DSDE_2023s2/main/code/Week03_ML/mushroom2020_dataset.csv')

# %%
# na in gill-size
df["gill-size"].isnull().sum()
# Out:
# 121

# %%
# 2
df = df.dropna(subset=['label'])

# %%
# 3
df = df.drop(columns=['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate',
                      'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
                      'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'])

# %%
# 4
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5764 entries, 0 to 5823
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   label              5764 non-null   object
#  1   cap-shape          5764 non-null   object
#  2   cap-surface        5737 non-null   object
#  3   bruises            5665 non-null   object
#  4   odor               5665 non-null   object
#  5   stalk-shape        5643 non-null   object
#  6   ring-number        5702 non-null   object
#  7   ring-type          5702 non-null   object
#  8   spore-print-color  5708 non-null   object
#  9   population         5708 non-null   object
#  10  habitat            5733 non-null   object
#  11  cap-color-rate     5737 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 585.4+ KB
# None

# %%
# 5
for col in df.columns:
    if df[col].dtype == np.number:
        df[col].fillna(df[col].mean(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /var/folders/f5/rsv9r9ld4vl6ylvcl4klm1380000gn/T/ipykernel_43787/1647036925.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[col].dtype == np.number:

# %%
df
# Out:
#      label cap-shape cap-surface bruises odor stalk-shape ring-number  \
# 0        p         x           s       t    p           e           o
# 1        e         x           s       t    a           e           o
# 2        e         b           s       t    l           e           o
# 3        p         x           y       t    p           e           o
# 4        e         x           s       f    n           t           o
# ...    ...       ...         ...     ...  ...         ...         ...
# 5819     e         k           s       f    n           e           o
# 5820     e         x           s       f    n           e           o
# 5821     e         f           s       f    n           e           o
# 5822     p         k           y       f    y           t           o
# 5823     e         x           s       f    n           e           o
#
#      ring-type spore-print-color population habitat  cap-color-rate
# 0            p                 k          s       u             1.0
# 1            p                 n          n       g             2.0
# 2            p                 n          n       m             3.0
# 3            p                 k          s       u             3.0
# 4            e                 n          a       g             4.0
# ...        ...               ...        ...     ...             ...
# 5819         p                 b          c       l             1.0
# 5820         p                 b          v       l             1.0
# 5821         p                 b          c       l             1.0
# 5822         e                 w          v       l             1.0
# 5823         p                 o          c       l             1.0
#
# [5764 rows x 12 columns]

# %%
# 6
df['label'] = df['label'].map({'e': 1, 'p': 0})
print(df['label'].value_counts())
# Out:
# label
# 0    3660
# 1    2104
# Name: count, dtype: int64

# %%
# 7
df = pd.get_dummies(df, drop_first=True)

# %%
# 8
X = df.drop('label', axis=1)
y = df['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2020)
print("training set:", y_train.shape[0])
print("testing set:", y_test.shape[0])
# Out:
# training set: 4611
# testing set: 1153

# %%
# 9
param_grid = {
    'criterion':['gini','entropy'],
    'max_depth': [2,3,6],
    'min_samples_leaf':[2,5,10],
    'n_estimators':[100,200],
    'random_state': [2020]
}
rf = RandomForestClassifier()
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 6], 'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [100, 200], 'random_state': [2020]})

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'n_estimators': 100, 'random_state': 2020}

# %%
# 10
y_pred = grid_search.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[731   1]
#  [  5 416]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       732
#            1       1.00      0.99      0.99       421
#
#     accuracy                           0.99      1153
#    macro avg       1.00      0.99      0.99      1153
# weighted avg       0.99      0.99      0.99      1153

# %%
# pipeline in sklearn
num_features = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = X_train.select_dtypes(include=['object']).columns.tolist()

num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_features),
        ('cat', cat_transformer, cat_features)
    ])

clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(random_state=2020))])

# %%
param_grid = {
    'classifier__criterion': ['gini', 'entropy'],
    'classifier__max_depth': [2, 3, 6],
    'classifier__min_samples_leaf': [2, 5, 10],
    'classifier__n_estimators': [100, 200]
}

grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['cap-color-rate']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore'))]),
#                                                                          [])])),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=2020))]),
#              param_grid={'classifier__criterion': ['gini', 'entropy'],
#                          'classifier__max_depth': [2, 3, 6],
#                          'classifier__min_samples_leaf': [2, 5, 10],
#                          'classifier__n_estimators': [100, 200]})

# %%
print(grid_search.best_params_)
# Out:
# {'classifier__criterion': 'gini', 'classifier__max_depth': 2, 'classifier__min_samples_leaf': 2, 'classifier__n_estimators': 100}

# %%
y_pred = grid_search.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[728   4]
#  [418   3]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.99      0.78       732
#            1       0.43      0.01      0.01       421
#
#     accuracy                           0.63      1153
#    macro avg       0.53      0.50      0.39      1153
# weighted avg       0.56      0.63      0.50      1153

# %%
# MLflow
mlflow.set_tracking_uri("file:///Users/inwpuun/mlruns")

# %%
with mlflow.start_run():
    mlflow.log_param("max_depth", 2)
    mlflow.log_param("n_estimators", 100)
    
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', RandomForestClassifier(max_depth=2, n_estimators=100, random_state=2020))])
    clf.fit(X_train, y_train)
    mlflow.sklearn.log_model(clf, "model")
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("accuracy", accuracy)
    
    print(f"Model accuracy: {accuracy}")
# Out:
# Model accuracy: 0.6339982653946227
